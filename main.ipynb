# %%
from dataPreprocess import DataProcesser
from sklearn.model_selection import train_test_split
from pandas import DataFrame

# %%
dp = DataProcesser()
data = dp.getData()
data = DataFrame(data).to_numpy()
print(data)
# Out:
# wating...
# wating...
# wating...
# wating...
# wating...
#                                                   ACC                    ECG  \
# 25  [0.37059998512268066, -0.056599974632263184, -...  [-0.0713653564453125]
# 30  [0.2849999666213989, -0.09820002317428589, -0....  [-0.0581817626953125]
# 29  [0.37619996070861816, -0.051599979400634766, -...  [-0.0600128173828125]
# 77  [0.639799952507019, 0.045600056648254395, -0.6...  [-0.1143035888671875]
# 74  [0.6948000192642212, 0.02820003032684326, -0.6...   [0.1050567626953125]
# ..                                                ...                    ...
# 43  [0.6765999794006348, 0.031599998474121094, -0....    [-0.03753662109375]
# 22  [0.3977999687194824, -0.06480002403259277, -0....   [0.0794219970703125]
# 72  [0.6588000059127808, 0.03040003776550293, -0.7...  [-0.3500518798828125]
# 15  [0.27779996395111084, -0.09039998054504395, -0...   [0.0010528564453125]
# 40  [0.7877999544143677, 0.000800013542175293, -0....   [0.1949615478515625]
#
#                       EMG                   EDA                 resp  \
# 25  [-0.0167999267578125]  [5.2883148193359375]  [-1.99127197265625]
# 30  [-0.0275115966796875]    [5.52825927734375]   [1.30157470703125]
# 29  [-0.0011444091796875]  [5.3188323974609375]  [-1.97296142578125]
# 77   [0.0047149658203125]  [7.3284149169921875]   [4.18548583984375]
# 74  [-0.0163421630859375]  [7.0491790771484375]     [2.911376953125]
# ..                    ...                   ...                  ...
# 43    [-0.00054931640625]  [7.1865081787109375]  [-1.59454345703125]
# 22    [-0.04083251953125]   [5.323028564453125]  [-2.96783447265625]
# 72   [0.0065460205078125]   [7.357025146484375]   [2.45208740234375]
# 15   [-0.002655029296875]    [5.53131103515625]   [1.63421630859375]
# 40  [-0.0092010498046875]  [7.1605682373046875]    [5.2825927734375]
#
#                     temp  label
# 25  [33.149139404296875]      1
# 30  [33.629180908203125]      1
# 29   [33.00482177734375]      1
# 77     [34.240478515625]      2
# 74   [34.02703857421875]      2
# ..                   ...    ...
# 43     [34.130615234375]      2
# 22  [33.290740966796875]      1
# 72  [34.258819580078125]      2
# 15  [33.641326904296875]      1
# 40   [33.84149169921875]      2
#
# [80 rows x 7 columns]

# %%
label = data.drop("label", axis= 1)
xTrain, xTest, yTrain, yTest = train_test_split(data, label, test_size=0.2, random_state=302)
